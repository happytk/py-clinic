# %%
import os
test_str = os.__doc__
# test_str을 단어조합으로 만들어보세요. 총 몇개인가요?

# test_str을 중복되지 않는 목록으로 만들어보세요.

import sys
another_test_str = sys.__doc__
# # another_test_str 단어조합을 만들어보세요. 총 몇개인가요?

# another_test_str와 test_str의 중복된 단어목록을 만들어보세요.

# another_test_str에만 존재하는 단어조합을 만들어보세요.

import re
# re를 이용해서 온전한 영어글자만의 조합으로 결과물을 생성해보세요

# %%
test_words = test_str.split()
len(test_words)
# Out:
# 182

# %%
test_words = set(test_words)
len(test_words)
# Out:
# 115

# %%
another_test_words = set(another_test_str.split())
len(another_test_words)
# Out:
# 241

# %%
test_words & another_test_words
# Out:
# {'(or',
#  'This',
#  'a',
#  'all',
#  'and',
#  'are',
#  'by',
#  'current',
#  'file',
#  'for',
#  'functions',
#  'in',
#  'is',
#  'line',
#  'of',
#  'only',
#  'or',
#  'path',
#  'pathname',
#  'search',
#  'string',
#  'that',
#  'the',
#  'to',
#  'used'}

# %%
another_test_words - test_words
# Out:
# {"''",
#  '(plus',
#  '--',
#  ':-)',
#  'By',
#  'Dynamic',
#  'Functions:',
#  'I/O.',
#  'Python',
#  'Static',
#  'SystemExit',
#  'These',
#  'To',
#  'Unicode',
#  '__displayhook__',
#  '__excepthook__',
#  '__stderr__',
#  '__stdin__',
#  '__stdout__',
#  'about',
#  'absolute',
#  'access',
#  'after',
#  'algorithm.',
#  'an',
#  'any',
#  'arguments;',
#  'argv',
#  'argv[0]',
#  'as',
#  'assign',
#  'assigning',
#  'available',
#  'be',
#  'been',
#  'behave',
#  'binary',
#  'built',
#  'builtin_module_names',
#  'builtins._',
#  'bytes',
#  'called',
#  'calls',
#  'checks',
#  'code',
#  'command',
#  'containers.',
#  'control',
#  'copyright',
#  'count',
#  'custom',
#  'customize',
#  'debug',
#  'depth',
#  'dictionary',
#  'directory,',
#  'displayhook',
#  'displayhook()',
#  'displayhook;',
#  'dlopen()',
#  "don't",
#  'else',
#  'encoded',
#  'error',
#  'events',
#  'exc_info()',
#  'excepthook',
#  'excepthook()',
#  'excepthook;',
#  'exception',
# ...
