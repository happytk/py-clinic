# %%
VIEWS_PERMISSION = {
    'admin.index':                             '',
    'ajax_post_tst':                           '',
    'board.download':                          '',
    'board.index':                             'check_project_member',
    'board.post_delete':                       'check_project_member',
    'board.post_modify':                       'check_project_member',
    'board.post_view':                         'check_project_member',
    'board.post_write':                        'check_project_member',
    'board.replysave':                         'check_project_member',
    'erc.blank':                               '',
    'erc.dwonload_template_excel_file':        '',
    'erc.ercapp':                              'check_project_member',
    'erc.erdMgmt':                             'check_project_modeler',
    'erc.get_Ent_Dtl':                         'check_project_member',
    'erc.get_Ent_Tbl_Dtl':                     'check_project_member',
    'erc.get_Memo':                            'check_project_member',
    # 'erc.get_Sja_Ent_Rel':                     'check_project_member',
    'erc.get_Tbl_Dtl':                         'check_project_member',
    'erc.get_current_lock_info':               'check_project_member',
    'erc.get_domain_list':                     'check_project_member',
    'erc.get_entity_list':                     'check_project_member',
    # 'erc.get_entity_subj_list':                'check_project_member',
    'erc.get_file_subj_tree':                  'check_project_member',
    'erc.get_glossary_list':                   'check_project_member',
    'erc.get_lock':                            'check_project_member',
    'erc.get_model_version_info':              'check_project_member',
    'erc.get_sjatree_version_info':            'check_project_member',
    # 'erc.get_subj_tree':                       'check_project_member',
    'erc.parse_Uploaded_Erd_File':             'check_project_member',
    'erc.release_lock':                        'check_project_member',
    'erc.resource':                            'check_project_member',
    'erc.save_ERD':                            'check_project_modeler',
    'erc.set_subj_tree':                       'check_project_member',
    'erc.upload_erd_file':                     'check_project_modeler',
    'erc.upload_excel_file':                   'check_project_modeler',
    'erc.download_template_excel_file':        'check_project_member',
    'erc.get_Sja_Ent_Rel':                     'check_project_member',
    'erc.get_entity_subj_list':                'check_project_member',
    'erc.get_memo_content':                    'check_project_member',
    'erc.get_memo_list':                       'check_project_member',
    'erc.get_subj_tree':                       'check_project_member',
    'erc.save_Memo':                           'check_project_modeler',
    'erc.static': '',
    'ercc_components.static':                  '',
    'ercc_components.template_index':          '',
    'glossary.codeset_codedel':                'check_project_termmgr',
    'glossary.codeset_modify':                 'check_project_termmgr',
    'glossary.codeset_modify_ajax':            'check_project_termmgr',
    'glossary.codeset_new':                    'check_project_termmgr',
    'glossary.codeset_reset':                  'check_project_termmgr',
    'glossary.codeset_view':                   'check_project_member',
    'glossary.glossary_del':                   'check_project_termmgr',
    'glossary.glossary_list':                  'check_project_member',
    'glossary.glossary_modify':                'check_project_termmgr',
    'glossary.glossary_new':                   'check_project_termmgr',
    'glossary.glossary_view':                  'check_project_member',
    'glossary._strd_term_codelist':            '', # erwin-plugin
    'glossary._strd_term_list':                '', # erwin-plugin
    'glossary.codeset_modify_json': 'check_project_member',
    'glossary.static': '',
    'infotype.delete_infotype':                'check_project_member',
    'infotype.dwonload_template_excel_file':   'check_project_member',
    'infotype.get_infotype_error_list':        'check_project_member',
    'infotype.get_infotype_input':             'check_project_member',
    'infotype.get_infotype_list':              'check_project_member',
    'infotype.glossary_view':                  'check_project_member',
    'infotype.modify_infotype':                'check_project_member',
    'infotype.upload_excel_infotype':          'check_project_member',
    'infotype.download_template_excel_file':   'check_project_member',
    'infotype.static':                          '',
    'login.change_password':                   'login_required',
    'login.confirm_notification':              'login_required',
    'login.delete_profile_img':                'login_required',
    'login.forget_password':                   '',
    'login.get_notifications':                 'login_required',
    'login.login':                             '',
    'login.logout':                            'login_required',
    'login.password_verify':                   '',
    'login.profile':                           'login_required',
    'login.profile_edit':                      'login_required',
    'login.profile_img':                       'login_required',
    'login.profile_timg':                      'login_required',
    'login.signup':                            '',
    'login.verify':                            '',
    'login.verify_guide':                      '',
    'login._profile':                          'login_required',
    'login.resend_verifying_mail':             '',
    'login.static':                            '',
    'portal.get_projects':                     '',
    'portal.index':                            '',
    'portal.raise_exception':                  '',
    'portal.search':                           'login_required',
    'portal.search_with_paging':               'login_required',
    'portal._projects_all':                    'login_required',
    'portal._projects_invited':                'login_required',
    'portal._projects_mine':                   'login_required',
    'portal._projects_picked':                 'login_required',
    'portal._projects_recommend':                      'login_required',
    'portal._projects_visited':                        'login_required',
    'portal.about':                             '',
    'portal.default_project_group_index':       '',
    'portal.download_file':                     '',
    'portal.projects':                          'login_required',
    'portal.projects_more':                     'login_required',
    'portal.raise_exception_test':              '',
    'project.create_project': 'login_required',
    'project.approve_all':                     'check_project_owner',
    'project.approve_user':                    'check_project_owner',
    'project.ban_user':                        'check_project_owner',
    'project.cancel_invitation':               'check_project_owner',
    'project.create':                          'login_required',
    'project.delegate_user':                   'check_project_owner',
    'project.delete_profile_img':              'check_project_owner',
    'project.demo':                            '',
    'project.destroy':                         'check_project_owner',
    'project.entities_info':                   'check_project_member',
    'project.index':                           'check_project_member',
    'project.invite':                          'check_project_member',
    'project.join_request':                    '',
    'project.leave':                           'check_project_member',
    'project.members':                         'check_project_member',
    'project.preference':                      'check_project_owner',
    'project.profile_img':                     '',
    'project.profile_timg':                    '',
    'project.reject_all':                      'check_project_owner',
    'project.reject_user':                     'check_project_owner',
    'project.resend_invitation':               'check_project_member',
    'project._members':                        'check_project_member',
    'project.assign_role':                     'check_project_owner',
    'project.handle_join_request':             'check_project_owner',
    'project.member_search':                   'check_project_member',
    'project.revoke_role':                     'check_project_owner',
    'project.static':                          '',
    'report.attr_list':                        'check_project_member',
    'report.attr_report_excel':                'check_project_member',
    'report.down_excel':                       'check_project_member',
    'report.download_file':                    'check_project_member',
    'report.entity_list':                      'check_project_member',
    'report.entity_list_report_excel':         'check_project_member',
    'report.get_attr':                         'check_project_member',
    'report.get_attr_detail':                  'check_project_member',
    'report.get_entity':                       'check_project_member',
    'report.get_subject_list':                 '',
    'report.get_subject_list_in_project':      'check_project_member',
    'report.create_script':                    'check_project_member',
    'report.get_entities':                     'check_project_member',
    'report.get_excel_validate_subjectarea_with_glossary':                     'check_project_member',
    'report.get_model_list':                       'check_project_member',
    'report.get_report_main_view':                     'check_project_member',
    'report.get_subjectareas_list':                    'check_project_member',
    'report.static':                            '',
    'report.validate_subjectarea_with_glossary': 'check_project_member',
    'term.get_infotype_list':                  'check_project_member',
    'term.get_infotype_list_by_domain_id':     'check_project_member',
    'term.get_rep_unit_term_list':             'check_project_member',
    'term.get_term_composition_list':          'check_project_member',
    'term.get_term_detail':                    'check_project_member',
    'term.get_term_list':                      'check_project_member',
    'term.term_update':                        'check_project_member',
    'term.get_unit_term_list':                 'check_project_member',
    'term.strd_term_excel_parsing':            'check_project_termmgr',
    'term.term_delete':                        'check_project_member',
    'term.term_regist':                        'check_project_member',
    'term.term_update':                        'check_project_member',
    'term.get_term_excel':                     'check_project_member',
    'term.unit_term_excel_parsing':            'check_project_termmgr',
    'term.upload_term_excel':                  'check_project_termmgr',
    'term._codeterm_search':                   'check_project_member',
    'term._entity_search':                     'check_project_member',
    'term.code_instance_excel_parsing':        'check_project_member',
    'term.code_instance_modify_json':          'check_project_member',
    'term.download_code_instance_template_excel_file':      'check_project_member',
    'term.download_strd_template_excel_file':   'check_project_member',
    'term.download_unit_template_excel_file':   'check_project_member',
    'term.get_term_hist':                       'check_project_member',
    'term.get_term_history_detail':             'check_project_member',
    'term.term_process_approve':                'check_project_termmgr',
    'term.term_process_cancel':                 'check_project_member',
    'term.term_process_reject':                 'check_project_termmgr',
    'term.validate_code_id':                    'check_project_member',
    'term.validate_strdterm_name':              'check_project_member',
    'term.validate_unitterm_name':              'check_project_member',
    'term.static':                              '',
    'tools.model_tools':                       'check_project_member',
    'tools.create_script':                     'check_project_member',
    'tools.validate_subjectarea_with_glossary': 'check_project_member',
    'model_mgmt._model_mgmt': 'check_project_member',
    'model_mgmt.model_mgmt': 'check_project_member',
    'model_mgmt.static': '',
    'project_group._cancel_manager': 'login_required',
    'project_group._info': 'login_required',
    'project_group._invite': 'login_required',
    'project_group._invite_manager': 'login_required',
    'project_group._notices': 'login_required',
    'project_group._preference_members_autoinvite': 'login_required',
    'project_group._preference_members_list': 'login_required',
    'project_group._preference_notices': 'login_required',
    'project_group._preference_projects': 'login_required',
    'project_group._preference_projects_list': 'login_required',
    'project_group._preference_security': 'login_required',
    'project_group.banner_img': 'login_required',
    'project_group.brand_img': 'login_required',
    'project_group.change_default_projectg': 'login_required',
    'project_group.delete_banner_img': 'login_required',
    'project_group.delete_brand_img': 'login_required',
    'project_group.index': 'login_required',
    'project_group.list_members': 'login_required',
    'project_group.list_projects': 'login_required',
    'project_group.preference': 'login_required',
    'project_group.preference_join_rules': 'login_required',
    'project_group.preference_managers': 'login_required',
    'project_group.preference_members': 'login_required',
    'project_group.preference_notices': 'login_required',
    'project_group.preference_projects': 'login_required',
    'project_group.preference_security': 'login_required',
    'project_group.static': 'login_required',
}

# %%
for view, permission in VIEWS_PERMISSION.items():
    print(view, permission)
    if permission == '':
        A.append(view)
# Out:
# admin.index
# ajax_post_tst
# board.download
# board.index check_project_member
# board.post_delete check_project_member
# board.post_modify check_project_member
# board.post_view check_project_member
# board.post_write check_project_member
# board.replysave check_project_member
# erc.blank
# erc.dwonload_template_excel_file
# erc.ercapp check_project_member
# erc.erdMgmt check_project_modeler
# erc.get_Ent_Dtl check_project_member
# erc.get_Ent_Tbl_Dtl check_project_member
# erc.get_Memo check_project_member
# erc.get_Tbl_Dtl check_project_member
# erc.get_current_lock_info check_project_member
# erc.get_domain_list check_project_member
# erc.get_entity_list check_project_member
# erc.get_file_subj_tree check_project_member
# erc.get_glossary_list check_project_member
# erc.get_lock check_project_member
# erc.get_model_version_info check_project_member
# erc.get_sjatree_version_info check_project_member
# erc.parse_Uploaded_Erd_File check_project_member
# ...

# %%
from itertools import groupby
second_one = lambda x:x[1]
items = sorted(VIEWS_PERMISSION.items(), key=second_one)
grouped = groupby(items, second_one)

for k, g in grouped:
    print (k)
# Out:
# check_project_member
# check_project_modeler
# check_project_owner
# check_project_termmgr
# login_required

# %%
from itertools import groupby
second_one = lambda x:x[1]
items = sorted(VIEWS_PERMISSION.items(), key=second_one)
result = {}
for k, g in groupby(items, second_one):
    result[k] = [x[0] for x in g]
result
# Out:
# {'': ['admin.index',
#   'ajax_post_tst',
#   'board.download',
#   'erc.blank',
#   'erc.dwonload_template_excel_file',
#   'erc.static',
#   'ercc_components.static',
#   'ercc_components.template_index',
#   'glossary._strd_term_codelist',
#   'glossary._strd_term_list',
#   'glossary.static',
#   'infotype.static',
#   'login.forget_password',
#   'login.login',
#   'login.password_verify',
#   'login.signup',
#   'login.verify',
#   'login.verify_guide',
#   'login.resend_verifying_mail',
#   'login.static',
#   'portal.get_projects',
#   'portal.index',
#   'portal.raise_exception',
#   'portal.about',
#   'portal.default_project_group_index',
#   'portal.download_file',
#   'portal.raise_exception_test',
#   'project.demo',
#   'project.join_request',
#   'project.profile_img',
#   'project.profile_timg',
#   'project.static',
#   'report.get_subject_list',
#   'report.static',
#   'term.static',
#   'model_mgmt.static'],
#  'check_project_member': ['board.index',
# ...
